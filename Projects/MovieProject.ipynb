# %%
import numpy as np
import pandas as pd

# %%
imdb_df=pd.read_csv('/content/IMDB top 1000.csv')
imdb_df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# 0             R  142 min                         Drama   9.3       80.0
# ...

# %%
#The transposed DataFrame.

imdb_df.T
# Out:
#                                                            0    \
# Unnamed: 0                                                   0
# Title                       1. The Shawshank Redemption (1994)
# Certificate                                                  R
# Duration                                               142 min
# Genre                                                    Drama
# Rate                                                       9.3
# Metascore                                                 80.0
# Description  Two imprisoned men bond over a number of years...
# Cast         Director: Frank Darabont | Stars: Tim Robbins,...
# Info                         Votes: 2,295,987 | Gross: $28.34M
#
#                                                            1    \
# Unnamed: 0                                                   1
# Title                                  2. The Godfather (1972)
# Certificate                                                  R
# ...

# %%
imdb_df.shape
# Out:
# (1000, 10)

# %%
imdb_df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Certificate', 'Duration', 'Genre', 'Rate',
#        'Metascore', 'Description', 'Cast', 'Info'],
#       dtype='object')

# %%
imdb_df.dtypes
# Out:
# Unnamed: 0       int64
# Title           object
# Certificate     object
# Duration        object
# Genre           object
# Rate           float64
# Metascore      float64
# Description     object
# Cast            object
# Info            object
# dtype: object

# %%
imdb_df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# ...

# %%
#DataFrame.select_dtypes-Return a subset of the DataFrame’s columns based on the column dtypes.

imdb_df.select_dtypes(include=None,exclude=int)
imdb_df.select_dtypes(include=float,exclude=None)
# Out:
#      Rate  Metascore
# 0     9.3       80.0
# 1     9.2      100.0
# 2     9.0       84.0
# 3     9.0       90.0
# 4     8.9       94.0
# ..    ...        ...
# 995   8.0        NaN
# 996   8.0       86.0
# 997   8.0       72.0
# 998   8.1        NaN
# 999   8.1        NaN
#
# [1000 rows x 2 columns]

# %%
#df.Values-Return a Numpy representation of the DataFrame.

imdb_df.values
# Out:
# array([[0, '1. The Shawshank Redemption (1994)', 'R', ...,
#         'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#         'Director: Frank Darabont | Stars: Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler',
#         'Votes: 2,295,987 | Gross: $28.34M'],
#        [1, '2. The Godfather (1972)', 'R', ...,
#         'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.',
#         'Director: Francis Ford Coppola | Stars: Marlon Brando, Al Pacino, James Caan, Diane Keaton',
#         'Votes: 1,584,782 | Gross: $134.97M'],
#        [2, '3. The Dark Knight (2008)', 'PG-13', ...,
#         'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
# ...

# %%
#pandas.DataFrame.axes---It has the row axis labels and column axis labels as the only members. They are returned in that order.

imdb_df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['Unnamed: 0', 'Title', 'Certificate', 'Duration', 'Genre', 'Rate',
#         'Metascore', 'Description', 'Cast', 'Info'],
#        dtype='object')]

# %%
#pandas.DataFrame.ndim----Return an int representing the number of axes / array dimensions.

#Return 1 if Series. Otherwise return 2 if DataFrame.


imdb_df.ndim
# Out:
# 2

# %%
#DataFrame.size----Return an int representing the number of elements in this object.

##Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.
imdb_df.size
# Out:
# 10000

# %%
#pandas.DataFrame.shape
#Return a tuple representing the dimensionality of the DataFrame.
imdb_df.shape
# Out:
# (1000, 10)

# %%
'''pandas.DataFrame.memory_usage
DataFrame.memory_usage(index=True, deep=False)[source]
The memory usage can optionally include the contribution of the index and elements of object dtype.'''
imdb_df.memory_usage()
# Out:
# Index           128
# Unnamed: 0     8000
# Title          8000
# Certificate    8000
# Duration       8000
# Genre          8000
# Rate           8000
# Metascore      8000
# Description    8000
# Cast           8000
# Info           8000
# dtype: int64

# %%
'''pandas.DataFrame.empty
Indicator whether Series/DataFrame is empty.

True if Series/DataFrame is entirely empty (no items), meaning any of the axes are of length 0.

Returns  bool
If Series/DataFrame is empty, return True, if not return False.'''


imdb_df.empty
# Out:
# False

# %% [markdown]
# **pandas.DataFrame.set_flags**
# DataFrame.set_flags(*, copy=False, allows_duplicate_labels=None)
# -Return a new object with updated flags.
#
# Parameters
# copy:bool, default False
# -Specify if a copy of the object should be made.
#
# allows_duplicate_labels: bool, optional
# Whether the returned object allows duplicate labels.
# Returns:
# Series or DataFrame

# %%
imdb_df.flags.allows_duplicate_labels
# Out:
# True

# %%
'''pandas.DataFrame.astype
DataFrame.astype(dtype, copy=None, errors='raise')[source]
Cast a pandas object to a specified dtype dtype.'''

imdb_df.astype({'Rate':'int32'}).dtypes
# Out:
# Unnamed: 0       int64
# Title           object
# Certificate     object
# Duration        object
# Genre           object
# Rate             int32
# Metascore      float64
# Description     object
# Cast            object
# Info            object
# dtype: object

# %%
#pandas.DataFrame.convert_dtypes--Convert columns to the best possible dtypes using dtypes supporting pd.NA

imdb_df.convert_dtypes()
imdb_df.dtypes
# Out:
# Unnamed: 0       int64
# Title           object
# Certificate     object
# Duration        object
# Genre           object
# Rate           float64
# Metascore      float64
# Description     object
# Cast            object
# Info            object
# dtype: object

# %% [markdown]
# **pandas.DataFrame**.**infer_objects**
# DataFrame.infer_objects(copy=None)
# Attempt to infer better dtypes for object columns.
#
# Attempts soft conversion of object-dtyped columns, leaving non-object and unconvertible columns unchanged. The inference rules are the same as during normal Series/DataFrame construction.

# %%
imdb_df.infer_objects()
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# 0             R  142 min                         Drama   9.3       80.0
# ...

# %%
imdb_df.copy(deep=True)    #Make a copy of this object’s indices and data.
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# 0             R  142 min                         Drama   9.3       80.0
# ...

# %%
'''DataFrame.at
Similar to loc, in that both provide label-based lookups. Use at if you only need to get or set a single value in a DataFrame or Series.'''


imdb_df.at[999,'Rate']
# Out:
# 8.1

# %%
imdb_df.loc[999,'Rate']
# Out:
# 8.1

# %%
#same as iloc
imdb_df.iat[1,2]
# Out:
# 'R'

# %%
#DataFrame.iloc
imdb_df.iloc[1,2]
# Out:
# 'R'

# %%
imdb_df.Metascore.mean()
# Out:
# 81.00140449438203

# %%
imdb_df.isna()
# Out:
#      Unnamed: 0  Title  Certificate  Duration  Genre   Rate  Metascore  \
# 0         False  False        False     False  False  False      False
# 1         False  False        False     False  False  False      False
# 2         False  False        False     False  False  False      False
# 3         False  False        False     False  False  False      False
# 4         False  False        False     False  False  False      False
# ..          ...    ...          ...       ...    ...    ...        ...
# 995       False  False        False     False  False  False       True
# 996       False  False        False     False  False  False      False
# 997       False  False        False     False  False  False      False
# 998       False  False        False     False  False  False       True
# 999       False  False        False     False  False  False       True
#
#      Description   Cast   Info
# 0          False  False  False
# 1          False  False  False
# ...

# %%
imdb_df.isna().sum()
# Out:
# Unnamed: 0       0
# Title            0
# Certificate     27
# Duration         0
# Genre            0
# Rate             0
# Metascore      288
# Description      0
# Cast             0
# Info             0
# dtype: int64

# %%
imdb_df.isna().sum().sum()
# Out:
# 315

# %%
imdb_df.Certificate.isna().sum()
# Out:
# 27

# %%
#Filling missing values
imdb_df['Certificate'].fillna(imdb_df['Certificate'].value_counts().keys()[0])

imdb_df['Certificate'].isna().sum()
# Out:
# 27

# %%
imdb_df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# 0             R  142 min                         Drama   9.3       80.0
# ...

# %% [markdown]
# # filling of missing **values**

# %%
# Calculate the mean of the "Metascore" column
metascore_mean = imdb_df['Metascore'].mean()

# Fill missing values with the mean
imdb_df['Metascore'].fillna(metascore_mean, inplace=True)

# %%
# Calculate the mode of the "Certificate" column
certificate_mode = imdb_df['Certificate'].mode()[0]

# Fill missing values with the mode
imdb_df['Certificate'].fillna(certificate_mode, inplace=True)

# %%
imdb_df.isna().sum()
# Out:
# Unnamed: 0     0
# Title          0
# Certificate    0
# Duration       0
# Genre          0
# Rate           0
# Metascore      0
# Description    0
# Cast           0
# Info           0
# dtype: int64

# %%
high_rated_movies = imdb_df[imdb_df['Rate'] > 9]
print(high_rated_movies[['Title', 'Rate']])
# Out:
#                                 Title  Rate
# 0  1. The Shawshank Redemption (1994)   9.3
# 1             2. The Godfather (1972)   9.2

# %%
imdb_df["Cast"]
# Out:
# 0      Director: Frank Darabont | Stars: Tim Robbins,...
# 1      Director: Francis Ford Coppola | Stars: Marlon...
# 2      Director: Christopher Nolan | Stars: Christian...
# 3      Director: Francis Ford Coppola | Stars: Al Pac...
# 4      Director: Peter Jackson | Stars: Elijah Wood, ...
#                              ...
# 995    Director: Martin Brest | Stars: Al Pacino, Chr...
# 996    Directors: Ron Clements, John Musker | Stars: ...
# 997    Director: Oliver Stone | Stars: Kevin Costner,...
# 998    Director: Federico Fellini | Stars: Giulietta ...
# 999    Director: Akira Kurosawa | Stars: Toshirô Mifu...
# Name: Cast, Length: 1000, dtype: object

# %%
#filtering and Sorting

imdb_df[["Title","Genre","Cast"]]
# Out:
#                                                  Title  \
# 0                   1. The Shawshank Redemption (1994)
# 1                              2. The Godfather (1972)
# 2                            3. The Dark Knight (2008)
# 3                     4. The Godfather: Part II (1974)
# 4    5. The Lord of the Rings: The Return of the Ki...
# ..                                                 ...
# 995                       398. Scent of a Woman (1992)
# 996                                399. Aladdin (1992)
# 997                                    400. JFK (1991)
# 998                      301. Nights of Cabiria (1957)
# 999                        302. Throne of Blood (1957)
#
#                             Genre  \
# 0                           Drama
# 1                    Crime, Drama
# 2            Action, Crime, Drama
# 3                    Crime, Drama
# 4        Action, Adventure, Drama
# ..                            ...
# 995                         Drama
# ...

# %%
imdb_df.Cast.info
# Out:
# <bound method Series.info of 0      Director: Frank Darabont | Stars: Tim Robbins,...
# 1      Director: Francis Ford Coppola | Stars: Marlon...
# 2      Director: Christopher Nolan | Stars: Christian...
# 3      Director: Francis Ford Coppola | Stars: Al Pac...
# 4      Director: Peter Jackson | Stars: Elijah Wood, ...
#                              ...
# 995    Director: Martin Brest | Stars: Al Pacino, Chr...
# 996    Directors: Ron Clements, John Musker | Stars: ...
# 997    Director: Oliver Stone | Stars: Kevin Costner,...
# 998    Director: Federico Fellini | Stars: Giulietta ...
# 999    Director: Akira Kurosawa | Stars: Toshirô Mifu...
# Name: Cast, Length: 1000, dtype: object>

# %%
#Genre Analysis
genre_counts=imdb_df['Genre'].value_counts()
print(genre_counts)
highest_genre=genre_counts.idxmax()


print("The movie with highest genre is of:",highest_genre)
# Out:
# Drama                           98
# Biography, Drama                46
# Drama, Romance                  43
# Animation, Adventure, Comedy    34
# Crime, Drama                    34
#                                 ..
# Animation, Action, Drama         1
# Adventure, Drama, Musical        1
# Comedy, Drama, Sci-Fi            1
# Comedy, Crime, Romance           1
# Adventure, Mystery, Thriller     1
# Name: Genre, Length: 130, dtype: int64
# The movie with highest genre is of: Drama

# %%
#count the types of Certificate
certificate_counts=imdb_df['Certificate'].value_counts()
print(certificate_counts)
# Out:
# R            372
# Not Rated    200
# PG-13        165
# PG           105
# Passed        55
# Approved      45
# G             41
# TV-PG          7
# TV-MA          7
# GP             2
# TV-14          1
# Name: Certificate, dtype: int64

# %%
#Find the longest and shortest duration movie

longest_duration=imdb_df['Duration'].max()
shortest_duration=imdb_df['Duration'].min()
#print(longest_duration)

longest_duration_movie=imdb_df[imdb_df['Duration']==longest_duration]['Title'].values[0]
shortest_duration_movie=imdb_df[imdb_df['Duration']==shortest_duration]['Title'].values[0]
print("The longest duration movie is:",longest_duration_movie)
print("The shortest duration movie is:",shortest_duration_movie)
# Out:
# The longest duration movie is: 104. Reservoir Dogs (1992)
# The shortest duration movie is: 241. Finding Nemo (2003)

# %%
# which movie performs better audience wise?

highest_rating = imdb_df['Rate'].max()
best_movie = imdb_df.loc[imdb_df['Rate'] == highest_rating, ['Title','Rate']]

# Print the movie with the highest rating
print("Movie which performs  better according to audience is:", best_movie)
# Out:
# Movie which performs  better according to audience is:                                 Title  Rate
# 0  1. The Shawshank Redemption (1994)   9.3

# %%
# which movie performs better gross wise?
highest_gross_votes = imdb_df['Info'].max()
best_movie = imdb_df.loc[imdb_df['Info'] == highest_gross_votes, 'Title'].values[0]

# Print the movie with the highest gross and votes
print("Movie which performs  better according to gross value  is:", best_movie)
# Out:
# Movie which performs  better according to gross value  is: 17. Goodfellas (1990)

# %%
#Find the movie title with the director Ford Coppola

ford_coppola_movies = imdb_df[imdb_df['Cast'].str.contains("Ford Coppola")]

ford_coppola_movie_titles = ford_coppola_movies['Title']

# Print the movie titles
print("Movies directed by Ford Coppola:")
for title in ford_coppola_movie_titles:
    print(title)
# Out:
# Movies directed by Ford Coppola:
# 2. The Godfather (1972)
# 4. The Godfather: Part II (1974)
# 74. Apocalypse Now (1979)

# %%
#Find the stars of lord of the rings
lord_of_the_rings_stars = imdb_df.loc[imdb_df['Title'].str.contains("The Lord of the Rings"), 'Cast'].values[0]
print("Stars of 'The Lord of the Rings':", lord_of_the_rings_stars)
# Out:
# Stars of 'The Lord of the Rings': Director: Peter Jackson | Stars: Elijah Wood, Viggo Mortensen, Ian McKellen, Orlando Bloom

# %%
#Find the movies title with the Star Tom Hanks

Tom_Hanks_movies = imdb_df[imdb_df['Cast'].str.contains("Tom Hanks")]

Tom_Hanks_movie_titles = Tom_Hanks_movies['Title']

# Print the movie titles
print("Movies starred by Tom Hanks:")
for title in Tom_Hanks_movie_titles:
    print(title)
# Out:
# Movies starred by Tom Hanks:
# 12. Forrest Gump (1994)
# 24. Saving Private Ryan (1998)
# 25. The Green Mile (1999)
# 93. Toy Story 3 (2010)
# 102. Toy Story (1995)
# 242. Catch Me If You Can (2002)

# %%
#Find the top rated movie  with the Star Tom Hanks

tom_hanks_movies = imdb_df[imdb_df['Cast'].str.contains("Tom Hanks")]

# Sort the movies by rating in descending order
sorted_movies = tom_hanks_movies.sort_values('Rate', ascending=False)

# Get the top-rated movie(s) with Tom Hanks
top_rated_movie = sorted_movies.iloc[0]

# Print the top-rated movie with Tom Hanks
print("Top-rated movie with Tom Hanks:")
print(top_rated_movie[['Title', 'Rate']])
# Out:
# Top-rated movie with Tom Hanks:
# Title    12. Forrest Gump (1994)
# Rate                         8.8
# Name: 11, dtype: object
